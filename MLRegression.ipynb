# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicole-Wanjiru/SalesPredictionRegresssionML/blob/main/MLRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction To Maching Learning
# This is the art of making machines/computers intelligent just like humans without explicitly programming.This intelligence will be achieved by making them learn from data.
#
# ## Terms:
#  1. Artificial Intelligence (AI): AI is basically making computers think/reason and act just like humans. Human intelligence (learning, vision, communicate, motion) is mimiced/copied by machines.
#
#  #### Branches of AI
#  a. Machine Learning: Focuses on training computers to learn from historical data and then make future predictions e,g Patients diagnosis, sales forecasting,
#
#  b. Natural Language Processing: Focuses on making computers understand and interpret a natural language (not a programming language e.g speech/text) e,g chatbox, Sentiment Analysis etc.
#
#  c. Robotics: Deals with movements e,g Autonomous Vehicles
#
#  d. Computer Vision: It uses another branch called Deep Learning to make computers understand and see the environment just as humans do. eg Scanning X-Ray Images, Object Detection etc.

# %%
#ML is widely categorised into two branches:
# 1. Supervised Machine Learning:  Training is done using labelled data
# 2. Unsupervised Machine Learning: Training is done using unlabelled data i.e the data is categorised.
# a. X/Predictor/Independent variable or features
# b. Y/Predicted/Dependent Variable/Outcome labels

# It is divided into:
# a) Regression: Y is continuous(numerical) e,g profits or sales
# b) Classification: Y is categorical (text), e.g diagnosis

# %%
# Read The Advertising Data Set
#The Datset below can be used for Supervised learning because:
#a)TV, Radio and Newspapers they are the features
#b) Based on The Features, we are predicting the sales  (Labels)
#Regression
import pandas as pd
df = pd.read_csv('/content/Advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
# EDA:
#1. Statistical
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
# 2. Checking Empties:
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# Correlation:
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# <Axes: >

# %%
#Bi-variant Correlation
for i in ['TV', 'Radio', 'Newspaper']:
  sns.scatterplot(x=i, y='Sales', data=df)
  plt.title(f'sales vs {i}')
  plt.show

# %%
#MACHINE LEARNING
# SUPERVISED LEARNING
#STEP 1: Separate the dataset into x & Y
array = df.values
array.shape
# Out:
# (200, 4)

# %%
X= array[:, 0:3]
X.shape
# Out:
# (200, 3)

# %%
Y= array[:, 3]
Y.shape
# Out:
# (200,)

# %%
# STEP 2: DIVIDING THE RECORDS(ROWS) INTO TRAINING SETS (70%) AND TESTING SETS(30%)
from sklearn import model_selection
X_train, X_Test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
#STEP3: TRAINING THE MODEL
#TRAINING SETS(X_train,Y_train)
#SCIENTIFIC ALGORITHMS

# %%
#importing the algorithms
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression

# %%
#STEP 4: CROSS VALIDATION
# DETRMERMINE THE BEST ALGORITHM

# %%
#training
model = DecisionTreeRegressor()
model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
#STEP 5: MODEL EVALUATION: -> Process that determines the accuracy of the model
# ACCURACY
# REGRESSION - r2_score()
# MEAN ABSOLUTE ERROR

# %%
predictions = model.predict(X_Test)
predictions
# Out:
# array([18.5, 23.8, 18.9,  5.3, 23.8, 15.3, 22.6,  9.9, 12. , 16.6,  8.8,
#         8.6, 11.7,  1.6, 10.3, 12.9,  5.3, 17. ,  9.7, 20.2, 18.9, 15.3,
#        10.8, 23.8,  9.9,  8.7, 22.6, 12.2, 10.6,  4.8, 11.4, 10.1, 23.8,
#         9.3, 15.9, 23.8, 10.4, 18.9, 12.4,  6.6, 11.6, 12.6, 10.4,  9.9,
#        12. ,  8.8,  9.7, 15. ,  9.7, 11.8, 13.6, 12.6,  5.3,  5.3,  8.8,
#        11.2,  9.9, 24.2,  6.6, 11.4])

# %%
Y_test
# Out:
# array([16.9, 22.4, 21.4,  7.3, 24.7, 12.6, 22.3,  8.4, 11.5, 14.9,  9.5,
#         8.7, 11.9,  5.3, 10.3, 11.7,  5.5, 16.6, 11.3, 18.9, 19.7, 12.5,
#        10.9, 22.2,  9.3,  8.1, 21.7, 13.4, 10.6,  5.7, 10.6, 11.3, 23.7,
#         8.7, 16.1, 20.7, 11.6, 20.8, 11.9,  6.9, 11. , 12.8, 10.1,  9.7,
#        11.6,  7.6, 10.5, 14.6, 10.4, 12. , 14.6, 11.7,  7.2,  6.6,  9.4,
#        11. , 10.9, 25.4,  7.6, 11.7])

# %%
#METRICS
from sklearn.metrics import r2_score
accuracy = r2_score(predictions, Y_test) *100

# %%
#PREDICTIONS:
#SUMMARY
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
features = [[280,48,20]]
outcome = model.predict(features)
print(f"Model Predicted{outcome}")
print(f"Model Accuracy{accuracy}")
# Out:
# Model Predicted[27.]
# Model Accuracy94.93007234849009
